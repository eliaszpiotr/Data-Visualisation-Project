# %%
import pandas as pd

# %%
df = pd.read_csv("Data/US_Accidents_March23_sampled_500k.csv")
df.head()
# Out:
#           ID   Source  Severity                     Start_Time  \
# 0  A-2047758  Source2         2            2019-06-12 10:10:56
# 1  A-4694324  Source1         2  2022-12-03 23:37:14.000000000
# 2  A-5006183  Source1         2  2022-08-20 13:13:00.000000000
# 3  A-4237356  Source1         2            2022-02-21 17:43:04
# 4  A-6690583  Source1         2            2020-12-04 01:46:00
#
#                         End_Time  Start_Lat   Start_Lng    End_Lat  \
# 0            2019-06-12 10:55:58  30.641211  -91.153481        NaN
# 1  2022-12-04 01:56:53.000000000  38.990562  -77.399070  38.990037
# 2  2022-08-20 15:22:45.000000000  34.661189 -120.492822  34.661189
# 3            2022-02-21 19:43:23  43.680592  -92.993317  43.680574
# 4            2020-12-04 04:13:09  35.395484 -118.985176  35.395476
#
#       End_Lng  Distance(mi)  ... Roundabout Station   Stop Traffic_Calming  \
# 0         NaN         0.000  ...      False   False  False           False
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     500000 non-null  object
#  1   Source                 500000 non-null  object
#  2   Severity               500000 non-null  int64
#  3   Start_Time             500000 non-null  object
#  4   End_Time               500000 non-null  object
#  5   Start_Lat              500000 non-null  float64
#  6   Start_Lng              500000 non-null  float64
#  7   End_Lat                279623 non-null  float64
#  8   End_Lng                279623 non-null  float64
#  9   Distance(mi)           500000 non-null  float64
#  10  Description            499999 non-null  object
#  11  Street                 499309 non-null  object
#  12  City                   499981 non-null  object
#  13  County                 500000 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df["Start_Time"][1], df["End_Time"][1], df["Severity"][1]
# Out:
# ('2022-12-03 23:37:14.000000000', '2022-12-04 01:56:53.000000000', 2)

# %%
df = df.drop(columns=['Source', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'County', 'Zipcode', 'Country', 'Timezone',
       'Airport_Code', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight'])

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ID                 500000 non-null  object
#  1   Severity           500000 non-null  int64
#  2   Start_Time         500000 non-null  object
#  3   End_Time           500000 non-null  object
#  4   Start_Lat          500000 non-null  float64
#  5   Start_Lng          500000 non-null  float64
#  6   Street             499309 non-null  object
#  7   City               499981 non-null  object
#  8   State              500000 non-null  object
#  9   Weather_Timestamp  492326 non-null  object
#  10  Temperature(F)     489534 non-null  float64
#  11  Wind_Chill(F)      370983 non-null  float64
#  12  Humidity(%)        488870 non-null  float64
#  13  Pressure(in)       491072 non-null  float64
#  14  Visibility(mi)     488709 non-null  float64
# ...

# %%
df.to_csv('Data/data.csv', index=False)

# %%
print(df['State'].unique())
# Out:
# ['LA' 'VA' 'CA' 'MN' 'MA' 'OR' 'FL' 'TX' 'IN' 'MT' 'AL' 'AZ' 'NY' 'NC'
#  'SC' 'KS' 'MI' 'CO' 'GA' 'MD' 'IL' 'PA' 'NM' 'NV' 'NE' 'NJ' 'TN' 'UT'
#  'RI' 'MS' 'IA' 'WA' 'MO' 'OH' 'OK' 'CT' 'DC' 'AR' 'WV' 'KY' 'WI' 'NH'
#  'WY' 'DE' 'VT' 'ID' 'ME' 'ND' 'SD']

# %%
print(df["Severity"].value_counts())
# Out:
# Severity
# 2    398142
# 3     84520
# 4     13064
# 1      4274
# Name: count, dtype: int64

# %%
lst = list(df["Street"].unique())

# %%
for i in lst: 
    print(i)
# Out:
# Highway 19
#  Forest Ridge Dr
# Floradale Ave
# 14th St NW
#  River Blvd
# Lowell St
# I-5 N
#  Claremont Dr
#  Preston Rd
# I-65
# N Meridian St
# I-90 W
# Governors Dr
# Friars Rd
# N Scottsdale Rd
#  W Okeechobee Rd
# I-95 S
# Caroline St
# Mill St
#  NW 21st St
# I-40 W
# Bartee Ave
# I-565
# Longcreek Dr
# Maitland Blvd
# KS-5
#  Marvin Rd
# I-5 S
# US-23 N
# E Airport Ave
# I-25 S
# Watt Ave
# Scenic Hwy
# I-80 E
# I-75 S
# Dwight D Eisenhower Hwy N
# I-35 S
#  Beechwood Dr
# I-710 N
# Wrightsboro Rd
# Chastain Rd NW
#  E Highway 501
# Commonwealth Ave
# Bristol St S
# Haynes Bridge Rd
# Memorial Hwy N
# Norman Y Mineta Hwy
# San Diego Fwy S
# I-15 N
# State Highway 252
# Charlotte Hwy
# Santiam Hwy SE
#  Lake Underhill Rd
# I-880 N
# Day Creek Blvd
#  Carlisle Pike
# I-10
#  Pearman Dairy Rd
# Little East Neck Rd
# US-395
# Redwood Hwy N
# S 13th St
# I-805
# Union St
# Golden Strip Fwy S
# 21st Ave S
#  Dewey Ave
#  Cloverland Dr
# I-10 W
# CA-29
# I-64 W
#  S Highland Ave
# ...

# %%
# !pip install kagglehub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 2.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sobhanmoosavi/us-accidents")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 653M/653M [00:41<00:00, 16.3MB/s]
# Extracting files...
# Path to dataset files: /Users/eliasz/.cache/kagglehub/datasets/sobhanmoosavi/us-accidents/versions/13

# %% [markdown]
# Path to dataset files: /Users/eliasz/.cache/kagglehub/datasets/sobhanmoosavi/us-accidents/versions/13

# %%
df2 = pd.read_csv("/Users/eliasz/.cache/kagglehub/datasets/sobhanmoosavi/us-accidents/versions/13/US_Accidents_March23.csv")

# %%
# Upewnij się, że kolumna 'Start_Time' jest w formacie datetime
df2['Start_Time'] = pd.to_datetime(df2['Start_Time'], errors='coerce')


# Filtruj rekordy, które są z roku 2023
r_23 = df2[df2['Start_Time'].dt.year == 2023]
r_22 = df2[df2['Start_Time'].dt.year == 2022]
r_21 = df2[df2['Start_Time'].dt.year == 2021]
r_20 = df2[df2['Start_Time'].dt.year == 2020]
# Wyświetl liczbę rekordów z roku 2023
count_2023 = r_23.shape[0]
count_2022 = r_22.shape[0]
count_2021 = r_21.shape[0]
count_2020 = r_20.shape[0]

print(f"Liczba rekordów z roku 2020: {count_2020}")
print(f"Liczba rekordów z roku 2020: {count_2021}")
print(f"Liczba rekordów z roku 2020: {count_2022}")
print(f"Liczba rekordów z roku 2020: {count_2023}")
print(f"Suma: {count_2022 + count_2023}")
# Out:
# Liczba rekordów z roku 2020: 1161598
# Liczba rekordów z roku 2020: 1412433
# Liczba rekordów z roku 2020: 1268806
# Liczba rekordów z roku 2020: 166552
# Suma: 1435358

# %%
# Upewnij się, że kolumna 'Start_Time' jest w formacie datetime
df2['Start_Time'] = pd.to_datetime(df2['Start_Time'], errors='coerce')

# Filtruj dane, które są od roku 2020
df_filtered = df2[df2['Start_Time'].dt.year >= 2020]

# Wyświetl nowy zbiór danych
print(df_filtered.head())
# Out:
#               ID   Source  Severity          Start_Time             End_Time  \
# 512217  A-512230  Source2         1 2022-09-08 05:49:30  2022-09-08 06:34:53
# 512218  A-512231  Source2         1 2022-09-08 02:02:05  2022-09-08 04:31:32
# 512219  A-512232  Source2         1 2022-09-08 05:14:12  2022-09-08 07:38:17
# 512220  A-512233  Source2         1 2022-09-08 06:22:57  2022-09-08 06:52:42
# 512221  A-512234  Source2         2 2022-09-08 06:36:20  2022-09-08 07:05:58
#
#         Start_Lat   Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 512217  41.946796  -88.208092      NaN      NaN          0.00  ...      False
# 512218  34.521172 -117.958076      NaN      NaN          0.00  ...      False
# 512219  37.542839  -77.441780      NaN      NaN          0.00  ...      False
# 512220  40.896629  -81.178452      NaN      NaN          0.00  ...      False
# 512221  41.409359  -81.644318      NaN      NaN          1.91  ...      False
#
# ...

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4009389 entries, 512217 to 7246341
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             datetime64[ns]
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df_filtered.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  1156511
# End_Lng                  1156511
# Distance(mi)                   0
# Description                    4
# Street                      8468
# City                         143
# County                         0
# State                          0
# Zipcode                      862
# Country                        0
# Timezone                    3687
# Airport_Code               13593
# Weather_Timestamp          69626
# Temperature(F)             90122
# Wind_Chill(F)             120971
# Humidity(%)                96267
# Pressure(in)               77197
# Visibility(mi)             92498
# Wind_Direction            108460
# Wind_Speed(mph)           108418
# Precipitation(in)         173417
# ...

# %%
df_filtered = df_filtered.drop(columns=['Source', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'County', 'Zipcode', 'Country', 'Timezone',
       'Airport_Code', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
       'Astronomical_Twilight'])

print(df_filtered.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4009389 entries, 512217 to 7246341
# Data columns (total 32 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ID                 object
#  1   Severity           int64
#  2   Start_Time         datetime64[ns]
#  3   End_Time           object
#  4   Start_Lat          float64
#  5   Start_Lng          float64
#  6   Street             object
#  7   City               object
#  8   State              object
#  9   Weather_Timestamp  object
#  10  Temperature(F)     float64
#  11  Wind_Chill(F)      float64
#  12  Humidity(%)        float64
#  13  Pressure(in)       float64
#  14  Visibility(mi)     float64
#  15  Wind_Direction     object
#  16  Wind_Speed(mph)    float64
#  17  Precipitation(in)  float64
#  18  Weather_Condition  object
#  19  Amenity            bool
#  20  Bump               bool
#  21  Crossing           bool
#  22  Give_Way           bool
#  23  Junction           bool
# ...

# %%
df.to_csv('Data/data_20_23.csv', index=False)
